# %% [markdown]
# # PACKAGES IN PYTHON

# %%
from mycalculator import Sum,multiply_number

# %%
Sum
# Out:
# mycalculator.add__number.Sum

# %%
sumM=Sum(1,2,3,4)

# %%
sumM.add()
# Out:
# 10

# %%
name  ="python"
if name=="java" or "html":
    print("true")
else:
    print("false")
# Out:
# true
