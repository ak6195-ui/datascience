# %% [markdown]
# # PYTHON OS MODULE
#  1) os.getcwd(): get the current working directory
#  2) os.mkdir('path'):  create a new directory
#  3) os.chdir('path'): change the current working directory
#  4) os.listdir('path'):list the contents of a directory
#  5) os.rename('old name ','new name '):renames a file for directory
#  6) os.remove('file to delete'):removes a file
#  7) os.rmdir('dir to delete'):remove directory
#  8) os.path.dirname('path'):returns the name of the directory containing path name path
#  9) os.path.exists('path'):checks if the path already exists

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\My PC\\OneDrive\\Desktop\\datascience\\modules and package'

# %%
file_path="test/file.txt"
if  os.path.exists(file_path):
    pass
else:
    print("xaina")
# Out:
# xaina

# %%
os.rmdir("testt/") #cannot run 2 times

# %%
os.getcwd()
# Out:
# 'C:\\Users\\My PC\\OneDrive\\Desktop\\datascience\\modules and package'

# %%
os.path.join("test/","file.txt")
# Out:
# 'test/file.txt'

# %%
os.makedirs("test/",exist_ok=True)

# %%
os.listdir(".")
# Out:
# ['.ipynb_checkpoints', 'os.ipynb', 'test']

# %% [markdown]
# #  WORKING WITH ENVIRONMENRT VARIABLES

# %%
os.environ
# Out:
# environ{'ACLOCAL_PATH': 'C:\\Program Files\\Git\\mingw64\\share\\aclocal;C:\\Program Files\\Git\\usr\\share\\aclocal',
#         'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\My PC\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'HEHEHAHA',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONFIG_SITE': 'C:/Program Files/Git/etc/config.site',
#         'DISPLAY': 'needs-to-be-defined',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_10468_1262719628': '1',
#         'EFC_10468_1592913036': '1',
#         'EFC_10468_2283032206': '1',
#         'EFC_10468_2775293581': '1',
#         'EFC_10468_344590478': '1',
#         'EFC_10468_3789132940': '1',
#         'EXEPATH': 'C:\\Program Files\\Git',
# ...

# %%
os.environ["MYPASS"]="abikhadka"

# %%
os.environ
# Out:
# environ{'ACLOCAL_PATH': 'C:\\Program Files\\Git\\mingw64\\share\\aclocal;C:\\Program Files\\Git\\usr\\share\\aclocal',
#         'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\My PC\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'HEHEHAHA',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONFIG_SITE': 'C:/Program Files/Git/etc/config.site',
#         'DISPLAY': 'needs-to-be-defined',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_10468_1262719628': '1',
#         'EFC_10468_1592913036': '1',
#         'EFC_10468_2283032206': '1',
#         'EFC_10468_2775293581': '1',
#         'EFC_10468_344590478': '1',
#         'EFC_10468_3789132940': '1',
#         'EXEPATH': 'C:\\Program Files\\Git',
# ...

# %%
os.getenv("MYPASS")
# Out:
# 'abikhadka'

# %%
os.getenv("OneDrive")
# Out:
# 'C:\\Users\\My PC\\OneDrive'

# %% [markdown]
# #  DATE TIME MODULE
# 1) datetime.date
# 2) datetime.time
# 3) datetimr.datetime
# 4) datetime.timedelta:represents duration difference between two dates
# 5) datetime.tzinfo:abstract base clas that can be used to define zones

# %%
import datetime

# %%
date1=datetime.date(2016,2,3)

# %%
date1.day
date1.month
date1.year
# Out:
# 2016

# %%
today=datetime.date.today()

# %%
print(today)
# Out:
# 2026-02-03

# %%
today==date1
# Out:
# False

# %%
today - date1
# Out:
# datetime.timedelta(days=3653)

# %%
# time delta
year_10=datetime.timedelta(days=10*365)
today+year_10
# Out:
# datetime.date(2036, 2, 1)

# %%
import time

# %%
time.time()
time.ctime()
# Out:
# 'Tue Feb  3 22:16:55 2026'

# %%
print("abi")
time.sleep(2)
print("khadka")
# Out:
# abi
# khadka

# %% [markdown]
# # RANDOM MODULE
# 1.random.random():returns float between 0(inclusive) and 1(exclusive)
# 2.random.uniform(a,b):returns a random float between a and b (both inclusive)
# 3.random.randint(a,b):returns a random intiger between a and b (inclusive)
# 4.random.randrange(start,stop,step):returns a randomly selected element from given range

# %%
import random

# %%
a=random.randint(1,2)
a
# Out:
# 2

# %%
print(random.random())
# Out:
# 0.002114180333227078

# %%
random.uniform(1,3)
# Out:
# 1.629605110637608

# %%
random.randrange(0,10,2)
# Out:
# 8

# %% [markdown]
# # SEQUENCE RELATED FUNCTIONS
# 1. random.suffle(seq,random): not return anything but shuffels the original sequence in place
# 2. random.sample(population,k): returs a new list that contains k unique elements randomly from the given population (list,tupe or iterable)
# 3. random.choice(seq):returns the random elements from given seq
# 4. random.choices(population,weights=None,*,cum_weights=None,k=1):returns list of k elements randomly chosen from the population .you can provide optional erights or cum_weights arguments to specify the probablity distribution of the elements

# %%
cards=["nine","one","ace"]
random.choice(cards)
# Out:
# 'ace'

# %%
random.shuffle(cards)
print(cards)
# Out:
# ['one', 'nine', 'ace']

# %%
random.sample(cards,2)
# Out:
# ['nine', 'one']

# %%
random.choices(cards,weights=[0.8,0.3,0.1],k=4)
# Out:
# ['nine', 'one', 'one', 'one']

# %% [markdown]
# # DISTRIBUTION AND PROBABLITY DENSITY FUNCTIONS
# 1. random.triangular(low,high,mode): generate random number from a triangular distribution
# 2. random.gauss(mus,sigma): generates random float from a Gaussian distribution with mean mu and standard deviation sigma
# 3. random.normalvariate(mean,stdev):generates a random float from a normal(Gaussian) distribution with mean mean and standard deviation stdev
# 4. random.expovariate(lambd):generates random numbers from  an exponential distribution with rate parameter lambd
# 5. random.gammavariate(alpha,beta): generates random numbers from gamma distribution
# 6. random.betavariate(alpha,beta): generates a random float from a beta distribution with parameters alpha and beta
# 7. random.paretovariate(alpha):generates random float from a pareto distribution with shape parameter alpha
# 8. random.weibullvariate(alpha,beta): generates  arandom float from a weibull disturibution with  shape paramater alpha and scale parameter beta

# %%
import random

print(f'Triangular distribution: {random.triangular(0, 10, 5):.2f}')
print(f'Gaussian distribution: {random.gauss(0, 1):.2f}')
print(f'Normal distribution: {random.normalvariate(0, 1):.2f}')
print(f'Exponential distribution: {random.expovariate(1):.2f}')
print(f'Gamma distribution: {random.gammavariate(1, 1):.2f}')
print(f'Beta distribution: {random.betavariate(2, 5):.2f}')
print(f'Pareto distribution: {random.paretovariate(2):.2f}')
print(f'Weibull distribution: {random.weibullvariate(1, 1):.2f}')
# Out:
# Triangular distribution: 8.47
# Gaussian distribution: -1.03
# Normal distribution: -2.11
# Exponential distribution: 2.10
# Gamma distribution: 0.05
# Beta distribution: 0.39
# Pareto distribution: 1.25
# Weibull distribution: 1.20

# %% [markdown]
# # Randomness-related functions
# These functions are used to seed the random number generator or to generate random numbers using an external source of randomness.
# 1. random.seed(a=None, version=2): Initializes the random number generator. If a is not specified or is None, the current system time is used as the seed. This function is useful if you want to generate reproducible random sequences.

# %%
random.seed(456)

# %%
random.randint(1,100)
# Out:
# 96
