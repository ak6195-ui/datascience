# %%
import pandas as pd 
import numpy as np 
import matplotlib as plot

# %%
data =pd.read_csv("train.csv",delimiter=",",header=0)

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data[(data["Age"]>30)].sample()
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 621          622         1       1  Kimball, Mr. Edwin Nelson Jr  male  42.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 621      1      0  11753  52.5542   D19        S

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data["Name"].str.split(" ").apply(lambda x:x[0])
# Out:
# 0         Braund,
# 1        Cumings,
# 2      Heikkinen,
# 3       Futrelle,
# 4          Allen,
#           ...
# 886     Montvila,
# 887       Graham,
# 888     Johnston,
# 889         Behr,
# 890       Dooley,
# Name: Name, Length: 891, dtype: str

# %%
data[(data["Survived"]==1) & (data["Sex"]=="male")].sum()
# Out:
# PassengerId                                                51854
# Survived                                                     109
# Pclass                                                       220
# Name           Williams, Mr. Charles EugeneBeesley, Mr. Lawre...
# Sex            malemalemalemalemalemalemalemalemalemalemalema...
# Age                                                      2536.67
# SibSp                                                         42
# Parch                                                         39
# Ticket         2443732486981137882677199472661160124873834577...
# Fare                                                   4449.5418
# Cabin          D56A6C52D10 D12F4F2A31C93D35C106C22 C26F2E50B9...
# Embarked       SSSCSCSSSCSCSSSSSSSCCSSSSSSSSSSSQSSSSCSSSSSSSS...
# dtype: object

# %%
data.loc[:,["Name","Survived"]]
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %%
data.iloc[0,:]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
data[(data["Fare"]>100) &(data["Sex"]=="female")].head()
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 88            89         1       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                       Fortune, Miss. Mabel Helen  female  23.0      3
# 195                            Lurette, Miss. Elise  female  58.0      0
# 215                         Newell, Miss. Madeleine  female  31.0      1
# 258                                Ward, Miss. Anna  female  35.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 31       0  PC 17569  146.5208          B78        C
# 88       2     19950  263.0000  C23 C25 C27        S
# 195      0  PC 17569  146.5208          B80        C
# 215      0     35273  113.2750          D36        C
# ...

# %%
data[(data["Ticket"].str.split(" ").apply(lambda x: x[0])=="PC") & (data["Sex"]=="female")].size
# Out:
# 348

# %%
data[~data.Cabin.isna()].size
# Out:
# 2448

# %%
data.sample()
# Out:
#      PassengerId  Survived  Pclass                 Name     Sex  Age  SibSp  \
# 303          304         1       2  Keane, Miss. Nora A  female  NaN      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 303      0  226593  12.35  E101        Q

# %%
#DATA FILTERING 
data.at[10,"Name"]
# Out:
# 'Sandstrom, Miss. Marguerite Rut'

# %%
data.at[1,"Name"]
data.at[2,"Name"]
data.at[3,'Name']
data.at[4,'Name']
# Out:
# 'Allen, Mr. William Henry'

# %%
temp=data.iloc[42,]
data.where(data["Survived"]==1,other=temp,axis=1)
# Out:
#     PassengerId Survived Pclass  \
# 0            43        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4            43        0      3
# ..          ...      ...    ...
# 886          43        0      3
# 887         888        1      1
# 888          43        0      3
# 889         890        1      1
# 890          43        0      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                                  Kraeff, Mr. Theodor    male   NaN     0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                                  Kraeff, Mr. Theodor    male   NaN     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
data.sample()
data.isnull().sum()
data.where(~data["Cabin"].isnull(),other=data.iloc[1,],axis=1)
# Out:
#     PassengerId Survived Pclass  \
# 0             2        1      1
# 1             2        1      1
# 2             2        1      1
# 3             4        1      1
# 4             2        1      1
# ..          ...      ...    ...
# 886           2        1      1
# 887         888        1      1
# 888           2        1      1
# 889         890        1      1
# 890           2        1      1
#
#                                                   Name     Sex   Age SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# ..                                                 ...     ...   ...   ...
# ...
