# %%
import numpy as np 
import pandas as pd

# %%
wine=pd.read_csv("WineQT.csv",delimiter=",",header=0)

# %%
wine[wine["pH"]>4]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 933            5.4              0.74          0.0             1.2      0.041
# 935            5.0              0.74          0.0             1.2      0.041
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 933                 16.0                  46.0  0.99258  4.01       0.59
# 935                 16.0                  46.0  0.99258  4.01       0.59
#
#      alcohol  quality    Id
# 933     12.5        6  1316
# 935     12.5        6  1321
