# %%
import pandas as pd
import numpy as np

# %%
titanic=pd.read_csv("train.csv")

# %%
titanic.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
titanic[["Age","Pclass"]].plot(kind="scatter",x="Age",y="Pclass")
# Out:
# <Axes: xlabel='Age', ylabel='Pclass'>

# %% [markdown]
# # CHI SQUARE TEST

# %%
import scipy.stats as stats

# %%
contingency=pd.crosstab(titanic.Pclass,titanic.Survived)

# %%
chi2_score,pvalue,dof,expected=stats.chi2_contingency(contingency)

# %%
print(f"chi-square test value={round(chi2_score,3)}")
print(f"chi-square test p value ={round(pvalue,5)}")
# Out:
# chi-square test value=102.889
# chi-square test p value =0.0

# %%
c=pd.crosstab(titanic.Age,titanic.Fare)
chi_value,p_value,dof,expected=stats.chi2_contingency(c)
print(f"the chi score is {round(chi_value)}")
print(f"the p value is {round(p_value)}")
# Out:
# the chi score is 20220
# the p value is 0

# %%
chi_score,p_value,dof,expected=stats.chi2_contingency(pd.crosstab(titanic.Survived,titanic.Embarked))
print(f"the chi_value is {chi_value:.2f}")
print(f"the p_value is {p_value:.7f}")
# Out:
# the chi_value is 20220.41
# the p_value is 0.0000018
