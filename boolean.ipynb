# %%
ok=True
type(ok)

# %% [markdown]
# and :returns True if both are True ,otherwise False
# or:returns True if either operand is True ,otherwise False
# not : makes negative

# %%
a=True
b=False

# %%
a and b #&
# Out:
# False

# %%
a | b # or
# Out:
# True

# %%
not a
# Out:
# False

# %%
(4>5) and (7 != 0)
# Out:
# False

# %%
w=9-5-4
oo=bool(w)
print (oo) #0 means false and 1 means true
# Out:
# False
