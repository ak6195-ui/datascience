# %%
a=1234
type(a)
# Out:
# int

# %%
num=-123
print(num)
# Out:
# -123

# %%
pi=3.14
type(pi)
# Out:
# float

# %%
#complex number
vec=3-4j
type(vec)
# Out:
# complex

# %%
vec=complex(22,7)
vec
# Out:
# (22+7j)
