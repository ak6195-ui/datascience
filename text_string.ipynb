# %%
name="abi"
print(name)
type(name)
# Out:
# abi
# str

# %%
la="""abi khadka """
print(la)
type(la)
# Out:
# abi khadka
# str

# %%
aa="123"
print(aa)
type(aa)
# Out:
# 123
# str

# %%
str(22)
# Out:
# '22'

# %%
#string are iterable 
#int and float are not iterable 
#use len to  check if it is iterable or not

# %% [markdown]
# string methods

# %%
print(name.upper())
# Out:
# ABI

# %%
ok="JAJA"
print(ok.lower())
# Out:
# jaja

# %%
ok.strip("J") #removes last or first character 
#removes space normally
# Out:
# 'AJA'

# %%
ok.replace("J","A")
# Out:
# 'AAAA'

# %%
ok.split("A")
# Out:
# ['J', 'J', '']

# %%
email="abi@gmail.com"
lll=email.split("@")
print(lll)
# Out:
# ['abi', 'gmail.com']

# %%
if(lll[1]=="gmail.com"):
    print("ok")
else:
    print("no")
# Out:
# ok

# %%
#operators can be used

# %% [markdown]
# #slicing in python

# %%
uu="kathmandu"

# %%
uu[-9:-4:2]
# Out:
# 'ktm'

# %%
uu[::-2]
# Out:
# 'unmtk'

# %%
# Out:
# 'u'
