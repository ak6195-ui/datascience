# %%
#creating bytes object from a string binary data
b=b"\x00\x01"
#creating a bytes object from a list of integers representing the binary data
bk=bytes([0,1,2,3,4,5])
#creating a byte array object from a string of binary data
ba =bytearray(b"\x00\x01")
#creating a bytearray object from a list of integers representing tha binary data
bl=bytearray([0,1,2,3,4,5])

# %%
type(b)
# Out:
# bytes

# %%
print(bk)
# Out:
# b'\x00\x01\x02\x03\x04\x05'

# %%
print(bl)
# Out:
# bytearray(b'\x00\x01\x02\x03\x04\x05')
