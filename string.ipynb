# %%
la="alai"

# %%
type(la)
# Out:
# str

# %%
la.upper()
# Out:
# 'ALAI'

# %%
la.lower()
# Out:
# 'alai'

# %%
la.replace("b","k")
# Out:
# 'alai'

# %%
la.strip()# space dinxa
# Out:
# 'alai'

# %%
la.split() #list ma convert garxa
# Out:
# ['alai']

# %%
type(la)
# Out:
# str

# %%
ok = ["a","b","c"]

# %%
type(ok)
# Out:
# list

# %%
lala="-".join(ok)

# %%
print(lala)
# Out:
# a-b-c

# %%
type(lala)
# Out:
# str

# %% [markdown]
# #slicing

# %%
aa ="abcdcdab"

# %%
aa[1:3]
# Out:
# 'bc'

# %%
aa[::2]
# Out:
# 'acca'

# %%
aa[::-1]
# Out:
# 'badcdcba'

# %% [markdown]
# string formatting
# f-string

# %%
name="abi"
age=12
la="my name is %s and my age is %d"%(name.upper(),age)
print(la)
# Out:
# my name is ABI and my age is 12

# %%
print(f"my name is {name.upper()} and my age is {age}")
# Out:
# my name is ABI and my age is 12

# %%
#print(t"my name is {name.upper()} and my age is {age}")
