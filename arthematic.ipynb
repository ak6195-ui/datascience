# %%
x=22
y=33

# %%
x+y
# Out:
# 55

# %%
y-x
# Out:
# 11

# %%
x*y
# Out:
# 726

# %%
x**2
# Out:
# 484

# %%
x/y
# Out:
# 0.6666666666666666

# %%
10%2
# Out:
# 0

# %%
11//2
# Out:
# 5

# %% [markdown]
# Type conversion

# %%
x=33

# %%
y = float(x)
y
# Out:
# 22.0

# %%
ee=1.11

# %%
int(ee)
# Out:
# 1

# %%
complex(33,88.5)

# %% [markdown]
#  # Comparison Operation

# %%
ala = 33
blb = 33

# %%
ala == blb
# Out:
# True

# %%
ala != blb
# Out:
# False

# %%
ala <= blb
# Out:
# True

# %% [markdown]
# Math function

# %%
import math

# %%
math.factorial(6)
# Out:
# 720

# %%
math.sqrt(81)

# %%
math.cbrt(81)
# Out:
# 4.326748710922225
