# %% [markdown]
# # DUNDERS= __

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __str__(self):
        return f"{self.name},{self.age} "
    def __repr__(self):
        return f"{self.name},b{self.age} "
    def __len__(self):
        return self.age
    def __call__(self,gender="male"):
        return f"{self.name} is a {gender}"

# %%
person=Person("abi",18)

# %%
person.name
# Out:
# 'abi'

# %%
person.age
# Out:
# 18

# %%
print(person)
# Out:
# abi,18

# %%
person
# Out:
# abi,b18

# %%
len(person)
# Out:
# 18

# %%
person()
# Out:
# 'abi is a male'

# %%
class Point :
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def __str__(self):
        return f"point({self.a},{self.b})"
        
    def __add__(self,other):
        a= self.a + other.a
        b= self.b + other.b
        return Point(a,b)
    def __mul__(self,other):
        a= self.a * other.a
        b= self.b * other.b
        return Point(a,b)
    # __eq__ le chai equal check garxa 
    def __eq__(self,other):
        return self.a==other.a and self.b==other.b

# %%
a=Point(2,3)
b=Point(4,5)

# %%
print(a)
# Out:
# point(2,3)

# %%
c = a + b

# %%
print(c)
# Out:
# point(6,8)

# %%
cc = a * b

# %%
print(cc)
# Out:
# point(8,15)

# %%
a==b
# Out:
# False

# %%
# leap year 
# class Leap:
#     def __init__(self,year:list):
#         self.year=year
#     def __str__(self):
#         return f"YEAR:{self.year} \n"
def listyr(self):
    if self % 4==0  and self %100 !=0:
        return True
    else:
        return False

# %%
list1=list(range(2000,2025,4))

# %%
list1
# Out:
# [2000, 2004, 2008, 2012, 2016, 2020, 2024]

# %%
# ly=Leap(list1)

# %%
leapyear=[ii for ii in list1 if listyr(ii)]

# %%
leapyear
# Out:
# [2004, 2008, 2012, 2016, 2020, 2024]
