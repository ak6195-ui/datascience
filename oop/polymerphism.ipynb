# %% [markdown]
# # POLYMERPHISM IN PYTHON
# 1. Method overloading
# 2. Method overriding
# 3. Operator Overloading
# 4. Duck Typing

# %% [markdown]
# # DUCK TYPING

# %%
class Car:
    def drive(self):
        print ("driving a car")
class Bike :
    def drive(self):
        print("driving a bike")

# %%
def start(vec):
    vec.drive()

# %%
car =Car()
bike =Bike()

# %%
start(car)
# Out:
# driving a car
