# %% [markdown]
# # Method Overloading in Python

# %%
#class Example:
    #def add(self,a,b=0,c=0):
     #return a+b+c

# %%
class Example:
    def add(self,*args):
        return sum(args)

# %%
ex=Example()

# %%
ex.add(1,2,3,4)
# Out:
# 10
