# %%
import numpy as np 
import pandas as pd

# %%
#dataframe using list 
# using 2d list 
student=[[100,80,10],[90,30,7],[120,100,10],[80,50,2]]
pd.DataFrame(student,columns=["iq","marks","package"])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     30        7
# 2  120    100       10
# 3   80     50        2

# %%
#using dictonary 
student_dict={"name":["abi","rajesh","hehe","haha"],"iq":[100,90,120,80],"marks":[80,70,100,50],"package":[10,7,14,2]}
students=pd.DataFrame(student_dict)
students.duplicated().sum()
# Out:
# np.int64(0)

# %%
#using read csv 
movies=pd.read_csv("move.csv")
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
#movies_s=pd.read_csv("move.csv",index_col="title_x").squeeze("columns")
#movies_s

# %%
ipl=pd.read_csv("ipl.csv")
ipl.sample()
# Out:
#          ID    City        Date Season MatchNumber           Team1  \
# 650  548360  Mumbai  2012-05-09   2012          54  Mumbai Indians
#
#                            Team2             Venue  \
# 650  Royal Challengers Bangalore  Wankhede Stadium
#
#                       TossWinner TossDecision SuperOver  \
# 650  Royal Challengers Bangalore        field         N
#
#                      WinningTeam    WonBy  Margin method Player_of_Match  \
# 650  Royal Challengers Bangalore  Wickets     9.0    NaN        CH Gayle
#
#                                           Team1Players  \
# 650  ['JEC Franklin', 'SR Tendulkar', 'RG Sharma', ...
#
#                                           Team2Players    Umpire1      Umpire2
# 650  ['TM Dilshan', 'CH Gayle', 'V Kohli', 'AB de V...  BF Bowden  VA Kulkarni

# %%
#ATTRIBUTES
ipl.shape
# Out:
# (950, 20)

# %%
ipl.size
# Out:
# 19000

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
ipl.values #gives in 2D numpy array
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl.tail(2)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam WonBy  Margin method  \
# 948          bat         N    Chennai Super Kings  Runs    33.0    NaN
# 949        field         N  Kolkata Knight Riders  Runs   140.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# ...

# %%
ipl.sample()
# Out:
#          ID       City        Date Season MatchNumber                Team1  \
# 82  1254095  Abu Dhabi  2021-10-06   2021          52  Sunrisers Hyderabad
#
#                           Team2                             Venue  \
# 82  Royal Challengers Bangalore  Zayed Cricket Stadium, Abu Dhabi
#
#                      TossWinner TossDecision SuperOver          WinningTeam  \
# 82  Royal Challengers Bangalore        field         N  Sunrisers Hyderabad
#
#    WonBy  Margin method Player_of_Match  \
# 82  Runs     4.0    NaN   KS Williamson
#
#                                          Team1Players  \
# 82  ['JJ Roy', 'Abhishek Sharma', 'KS Williamson',...
#
#                                          Team2Players Umpire1    Umpire2
# 82  ['V Kohli', 'D Padikkal', 'DT Christian', 'KS ...  S Ravi  UV Gandhe

# %%
movies.info() # to check missing value 
movies.dropna(inplace=True)
movies.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count     298.0       298.000000   298.000000     298.000000
# mean        0.0      2008.845638     6.361409   14193.617450
# std         0.0         5.192230     1.340469   26724.554265
# min         0.0      2001.000000     1.700000      25.000000
# 25%         0.0      2004.000000     5.400000    1801.250000
# 50%         0.0      2008.000000     6.600000    5225.500000
# 75%         0.0      2013.000000     7.400000   15041.250000
# max         0.0      2019.000000     8.500000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
ipl[ipl.isnull()]
# Out:
#      ID City Date Season MatchNumber Team1 Team2 Venue TossWinner  \
# 0   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 1   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 2   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 3   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 4   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# ..   ..  ...  ...    ...         ...   ...   ...   ...        ...
# 945 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 946 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 947 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 948 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 949 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
#
#     TossDecision SuperOver WinningTeam WonBy  Margin method Player_of_Match  \
# 0            NaN       NaN         NaN   NaN     NaN    NaN             NaN
# ...

# %%
movies.isnull().sum()
# Out:
# title_x             0
# imdb_id             0
# poster_path         0
# wiki_link           0
# title_y             0
# original_title      0
# is_adult            0
# year_of_release     0
# runtime             0
# genres              0
# imdb_rating         0
# imdb_votes          0
# story               0
# summary             0
# tagline             0
# actors              0
# wins_nominations    0
# release_date        0
# dtype: int64

# %%
ipl.duplicated().sum() # duplicate row
# Out:
# np.int64(0)

# %%
#rename 
students
# Out:
#      name   iq  marks  package
# 0     abi  100     80       10
# 1  rajesh   90     70        7
# 2    hehe  120    100       14
# 3    haha   80     50        2

# %%
students.rename(columns={"name":"nam"},inplace=True)
students.rename(columns={"iq":"dimag","marks":"rating"},inplace=True)
students 
students["rating"]=students["rating"].values/100
students
# Out:
#       nam  dimag  rating  package
# 0     abi    100     0.8       10
# 1  rajesh     90     0.7        7
# 2    hehe    120     1.0       14
# 3    haha     80     0.5        2

# %%
#MATHS METHODS 
students
# Out:
#       nam  dimag  rating  package
# 0     abi    100     0.8       10
# 1  rajesh     90     0.7        7
# 2    hehe    120     1.0       14
# 3    haha     80     0.5        2

# %%
students.sum(axis=0)
# Out:
# nam        abirajeshhehehaha
# dimag                    390
# rating                   3.0
# package                   33
# dtype: object

# %%
students.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 students.mean()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)  11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
# ...

# %%
students.mean(axis=1)
# Out:
# 0    63.333333
# 1    55.666667
# 2    78.000000
# 3    44.000000
# 4     0.000000
# 5     0.000000
# dtype: float64

# %%
students.max()
# Out:
# iq         120
# percent    100
# lpa         14
# dtype: int64

# %%
students.describe()
# Out:
#               iq     percent        lpa
# count    6.00000    6.000000   6.000000
# mean    65.00000   50.000000   5.500000
# std     52.05766   41.952354   5.787918
# min      0.00000    0.000000   0.000000
# 25%     20.00000   12.500000   0.500000
# 50%     85.00000   60.000000   4.500000
# 75%     97.50000   77.500000   9.250000
# max    120.00000  100.000000  14.000000

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   iq       6 non-null      int64
#  1   percent  6 non-null      int64
#  2   lpa      6 non-null      int64
# dtypes: int64(3)
# memory usage: 276.0 bytes

# %%
students.isnull()
# Out:
#       iq  percent    lpa
# 0  False    False  False
# 1  False    False  False
# 2  False    False  False
# 3  False    False  False
# 4  False    False  False
# 5  False    False  False

# %%
import matplotlib.pyplot as p
p.plot(students)

# %%
# SELECTING COLUMNS FROM DATAFRAME  -> DATA FETCH 
movies.sample()
# Out:
#      title_x    imdb_id                                        poster_path  \
# 314  Dishoom  tt3679060  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                  wiki_link title_y original_title  is_adult  \
# 314  https://en.wikipedia.org/wiki/Dishoom   Kapow        Dishoom         0
#
#      year_of_release runtime                   genres  imdb_rating  \
# 314             2016     124  Action|Adventure|Comedy          5.1
#
#      imdb_votes                                              story  \
# 314        5976  When India's top batsman Viraj goes missing in...
#
#                                                summary tagline  \
# 314  When India's top batsman goes missing in the M...     NaN
#
#                                                 actors       wins_nominations  \
# 314  John Abraham|Varun Dhawan|Nargis Fakhri|Jacque...  2 wins & 1 nomination
#
#            release_date
# 314  29 July 2016 (USA)

# %%
movies["title_x"]
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
ipl.sample()
ipl["Venue"]
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
#MULTIPLE COLUMNS 
movies[["title_x","year_of_release","actors"]].sort_values(by="year_of_release").head()
# Out:
#                             title_x  year_of_release  \
# 1625           Yeh Zindagi Ka Safar             2001
# 1624          Tera Mera Saath Rahen             2001
# 1623                       Zubeidaa             2001
# 1622  Yeh Teraa Ghar Yeh Meraa Ghar             2001
# 1621                        Tum Bin             2001
#
#                                                  actors
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1623  Karisma Kapoor|Rekha|Manoj Bajpayee|Rajit Kapo...
# 1622  Sunil Shetty|Mahima Chaudhry|Paresh Rawal|Saur...
# 1621  Priyanshu Chatterjee|Himanshu Malik|Sandali Si...

# %%
movies.rename(columns={"title_x":"movie_name"})
# Out:
#                                 movie_name     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#SELECTING ROWS AND COLUMNS 
students
#students.set_index("name",inplace=True)
# Out:
#          iq  marks  package
# name
# abi     100     80       10
# haha     80     50        2
# hehe    120    100       14
# rajesh   90     70        7

# %%
#SELECTING ROW -> 
# 1)iloc - searches using index positions 
# and 2) loc - searches using index labels

# %%
movies.iloc[0] # it is a series 
movies.head(3)
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
#
# ...

# %%
# MULTIPLE ROWS 
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# fancy indexing
movies.iloc[[0,2,4]]
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 37  Article 15 (film)  tt10324144
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link     title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy   Gully Boy
# 37  https://en.wikipedia.org/wiki/Article_15_(film)  Article 15
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)        Raid
#
#    original_title  is_adult  year_of_release runtime              genres  \
# 11      Gully Boy         0             2019     153         Drama|Music
# 37     Article 15         0             2019     130         Crime|Drama
# 96           Raid         0             2018     122  Action|Crime|Drama
#
#     imdb_rating  imdb_votes  \
# ...

# %%
lala=movies.set_index("title_x")
lala.loc["Gully Boy"]
# Out:
# array(['tt2395469',
#        'https://upload.wikimedia.org/wikipedia/en/thumb/0/07/Gully_Boy_poster.jpg/220px-Gully_Boy_poster.jpg',
#        'https://en.wikipedia.org/wiki/Gully_Boy', 'Gully Boy',
#        'Gully Boy', np.int64(0), np.int64(2019), '153', 'Drama|Music',
#        np.float64(8.2), np.int64(22440),
# ...

# %%
students
# Out:
#       nam  dimag  rating  package
# 0     abi    100     0.8       10
# 1  rajesh     90     0.7        7
# 2    hehe    120     1.0       14
# 3    haha     80     0.5        2

# %%
studentss= students.set_index("nam")
studentss.loc["abi":"haha"]#labeled data fetching 
# last one is also included in loc
# Out:
#         dimag  rating  package
# nam
# abi       100     0.8       10
# rajesh     90     0.7        7
# hehe      120     1.0       14
# haha       80     0.5        2

# %%
students.sort_values("dimag",ascending=False)
lala.head(3)
# Out:
#                       imdb_id  \
# title_x
# Gully Boy           tt2395469
# Yeh Hai India       tt5525846
# Article 15 (film)  tt10324144
#
#                                                          poster_path  \
# title_x
# Gully Boy          https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India      https://upload.wikimedia.org/wikipedia/en/thum...
# Article 15 (film)  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                          wiki_link  \
# title_x
# Gully Boy                  https://en.wikipedia.org/wiki/Gully_Boy
# Yeh Hai India          https://en.wikipedia.org/wiki/Yeh_Hai_India
# Article 15 (film)  https://en.wikipedia.org/wiki/Article_15_(film)
#
#                          title_y original_title  is_adult  year_of_release  \
# title_x
# Gully Boy              Gully Boy      Gully Boy         0             2019
# Yeh Hai India      Yeh Hai India  Yeh Hai India         0             2017
# ...

# %%
lala.iloc[[0,1,2,3],[0,1,2,3]]
# Out:
#                       imdb_id  \
# title_x
# Gully Boy           tt2395469
# Yeh Hai India       tt5525846
# Article 15 (film)  tt10324144
# Aiyaary             tt6774212
#
#                                                          poster_path  \
# title_x
# Gully Boy          https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India      https://upload.wikimedia.org/wikipedia/en/thum...
# Article 15 (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# Aiyaary            https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                          wiki_link  \
# title_x
# Gully Boy                  https://en.wikipedia.org/wiki/Gully_Boy
# Yeh Hai India          https://en.wikipedia.org/wiki/Yeh_Hai_India
# Article 15 (film)  https://en.wikipedia.org/wiki/Article_15_(film)
# Aiyaary                      https://en.wikipedia.org/wiki/Aiyaary
#
#                          title_y
# title_x
# Gully Boy              Gully Boy
# ...

# %%
movies.loc[0:2,"title_x":"poster_path"]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
lala
lala.loc["Uri: The Surgical Strike":"Why Cheat India","imdb_id":"story"]
# Out:
#                                         imdb_id  \
# title_x
# Uri: The Surgical Strike              tt8291224
# Battalion 609                         tt9472208
# The Accidental Prime Minister (film)  tt6986710
# Why Cheat India                       tt8108208
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# Why Cheat India                       https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                               wiki_link  \
# title_x
# Uri: The Surgical Strike              https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# ...

# %%
# DATA FETCHING PRACTICE 
ipl.sample()
#ipl[:,["Date","MatchNumber"=="Final","WinningTeam"]]
winning=(ipl["MatchNumber"]=="Final")
# winning 
win_df=ipl[winning]
win_df[["Date","WinningTeam","MatchNumber"]]
# Out:
#            Date            WinningTeam MatchNumber
# 0    2022-05-29         Gujarat Titans       Final
# 74   2021-10-15    Chennai Super Kings       Final
# 134  2020-11-10         Mumbai Indians       Final
# 194  2019-05-12         Mumbai Indians       Final
# 254  2018-05-27    Chennai Super Kings       Final
# 314  2017-05-21         Mumbai Indians       Final
# 373  2016-05-29    Sunrisers Hyderabad       Final
# 433  2015-05-24         Mumbai Indians       Final
# 492  2014-06-01  Kolkata Knight Riders       Final
# 552  2013-05-26         Mumbai Indians       Final
# 628  2012-05-27  Kolkata Knight Riders       Final
# 702  2011-05-28    Chennai Super Kings       Final
# 775  2010-04-25    Chennai Super Kings       Final
# 835  2009-05-24        Deccan Chargers       Final
# 892  2008-06-01       Rajasthan Royals       Final

# %%
ipl[ipl["WinningTeam"]=="Chennai Super Kings"] [ipl["MatchNumber"]=="Final"].iloc[:,[2,3,4,5,6,7,10,11,12]].sort_values(by="Date")
# Out:
# C:\Users\My PC\AppData\Local\Temp\ipykernel_109636\4076312210.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ipl[ipl["WinningTeam"]=="Chennai Super Kings"] [ipl["MatchNumber"]=="Final"].iloc[:,[2,3,4,5,6,7,10,11,12]].sort_values(by="Date")
#            Date   Season MatchNumber                Team1  \
# 775  2010-04-25  2009/10       Final  Chennai Super Kings
# 702  2011-05-28     2011       Final  Chennai Super Kings
# 254  2018-05-27     2018       Final  Sunrisers Hyderabad
# 74   2021-10-15     2021       Final  Chennai Super Kings
#
#                            Team2                                Venue  \
# 775               Mumbai Indians           Dr DY Patil Sports Academy
# 702  Royal Challengers Bangalore      MA Chidambaram Stadium, Chepauk
# 254          Chennai Super Kings                     Wankhede Stadium
# 74         Kolkata Knight Riders  Dubai International Cricket Stadium
#
#     SuperOver          WinningTeam    WonBy
# ...

# %%
ipl[ipl["SuperOver"]=="Y"].loc[:,["WinningTeam","WonBy","Date","Team1","Team2"]]
# Out:
#                      WinningTeam      WonBy        Date  \
# 114               Delhi Capitals  SuperOver  2021-04-25
# 158        Kolkata Knight Riders  SuperOver  2020-10-18
# 159              Kings XI Punjab  SuperOver  2020-10-18
# 184  Royal Challengers Bangalore  SuperOver  2020-09-28
# 192               Delhi Capitals  SuperOver  2020-09-20
# 203               Mumbai Indians  SuperOver  2019-05-02
# 244               Delhi Capitals  SuperOver  2019-03-30
# 339               Mumbai Indians  SuperOver  2017-04-29
# 474              Kings XI Punjab  SuperOver  2015-04-21
# 533             Rajasthan Royals  SuperOver  2014-04-29
# 608  Royal Challengers Bangalore  SuperOver  2013-04-16
# 621          Sunrisers Hyderabad  SuperOver  2013-04-07
# 819              Kings XI Punjab  SuperOver  2010-03-21
# 883             Rajasthan Royals  SuperOver  2009-04-23
#
#                            Team1                        Team2
# ...

# %%
ipl.sample(3)
ipl["Match"]=ipl["MatchNumber"].str.split(" ").apply(lambda x: x[0] )
ipl.sample()
# Out:
#          ID    City        Date Season  MatchNumber                Team1  \
# 436  829817  Mumbai  2015-05-19   2015  Qualifier 1  Chennai Super Kings
#
#               Team2             Venue      TossWinner TossDecision  ...  \
# 436  Mumbai Indians  Wankhede Stadium  Mumbai Indians          bat  ...
#
#         WinningTeam WonBy Margin  method Player_of_Match  \
# 436  Mumbai Indians  Runs   25.0     NaN      KA Pollard
#
#                                           Team1Players  \
# 436  ['DR Smith', 'MEK Hussey', 'F du Plessis', 'SK...
#
#                                           Team2Players          Umpire1  \
# 436  ['LMP Simmons', 'PA Patel', 'RG Sharma', 'KA P...  HDPK Dharmasena
#
#             Umpire2      Match
# 436  RK Illingworth  Qualifier
#
# [1 rows x 21 columns]

# %%
ipl[(ipl["City"]=="Kolkata") & (ipl["WinningTeam"]=="Chennai Super Kings")].loc[:,["WinningTeam","City","Date","Venue"]].shape[0]
# Out:
# 5

# %%
ipl[ipl["TossWinner"]==ipl["WinningTeam"]].shape[0]/ipl.shape[0]
# Out:
# 0.5147368421052632

# %%
movies.sample(3)
movies[(movies["imdb_votes"]>10000) & (movies["imdb_rating"]>8)].shape[0]
# Out:
# 43

# %%
movies[(movies["genres"]=="Action") & (movies["imdb_rating"]>7.)]
# Out:
#              title_x     imdb_id  \
# 367   Gabbar Is Back   tt2424988
# 368   Gabbar Is Back   tt2424988
# 1627           Daaka  tt10833860
#
#                                             poster_path  \
# 367   https://upload.wikimedia.org/wikipedia/en/thum...
# 368   https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                          wiki_link         title_y  \
# 367   https://en.wikipedia.org/wiki/Gabbar_Is_Back  Gabbar is Back
# 368   https://en.wikipedia.org/wiki/Gabbar_is_Back  Gabbar is Back
# 1627           https://en.wikipedia.org/wiki/Daaka           Daaka
#
#       original_title  is_adult  year_of_release runtime  genres  imdb_rating  \
# 367   Gabbar is Back         0             2015     128  Action          7.1
# 368   Gabbar is Back         0             2015     128  Action          7.1
# 1627           Daaka         0             2019     136  Action          7.4
#
# ...

# %%
movies[(movies["genres"].str.split("|").apply(lambda x: "Action" in x)) & (movies["imdb_rating"]>7.5)].loc[:,["title_x","imdb_rating"]]
# Out:
#                             title_x  imdb_rating
# 0          Uri: The Surgical Strike          8.4
# 41             Family of Thakurganj          9.4
# 84                        Mukkabaaz          8.1
# 106                           Raazi          7.8
# 110   Parmanu: The Story of Pokhran          7.7
# 112         Bhavesh Joshi Superhero          7.6
# 169                The Ghazi Attack          7.6
# 219                Raag Desh (film)          8.3
# 258                   Irudhi Suttru          7.6
# 280                       Laal Rang          8.0
# 297                     Udta Punjab          7.8
# 354                   Dangal (film)          8.4
# 362               Bajrangi Bhaijaan          8.0
# 365          Baby (2015 Hindi film)          8.0
# 393      Detective Byomkesh Bakshy!          7.6
# 449               Titli (2014 film)          7.6
# 536                   Haider (film)          8.1
# 589                    Vishwaroopam          8.2
# ...

# %%
movies[movies["genres"].str.contains("Action")]
# Out:
#                                title_x     imdb_id  \
# 0             Uri: The Surgical Strike   tt8291224
# 8     Manikarnika: The Queen of Jhansi   tt6903440
# 13                       Total Dhamaal   tt7639372
# 14                          Sonchiriya   tt8108200
# 16              Mard Ko Dard Nahi Hota   tt8055888
# ...                                ...         ...
# 1606   Hadh: Life on the Edge of Death   tt0396044
# 1607           Nayak (2001 Hindi film)   tt0291376
# 1608                        One 2 Ka 4   tt0227194
# 1617               Officer (2001 film)   tt0265452
# 1627                             Daaka  tt10833860
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 8     https://upload.wikimedia.org/wikipedia/en/thum...
# 13    https://upload.wikimedia.org/wikipedia/en/thum...
# 14    https://upload.wikimedia.org/wikipedia/en/thum...
# 16    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#ADDING NEW COLUMNS 
# 1) ADDING NEW COLUMN 
# 2) ADDING FROM EXISTING ONE 
movies["country"]="Nepal"

# %%
movies.sample()
# Out:
#          title_x    imdb_id  \
# 630  Grand Masti  tt2476154
#
#                                            poster_path  \
# 630  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                      wiki_link      title_y original_title  \
# 630  https://en.wikipedia.org/wiki/Grand_Masti  Grand Masti    Grand Masti
#
#      is_adult  year_of_release runtime                genres  imdb_rating  \
# 630         0             2013     137  Comedy|Drama|Romance          4.3
#
#      imdb_votes                                              story  \
# 630        5423  Meet  Prem  and Amar look to have a blast at t...
#
#                                                summary tagline  \
# 630  Meet  Prem  and Amar look to have a blast at t...     NaN
#
#                                                 actors  \
# 630  Vivek Oberoi|Riteish Deshmukh|Aftab Shivdasani...
#
#            wins_nominations             release_date country
# ...

# %%
movies.dropna(inplace=True)

# %%
movies["actors"].str.split("|").apply(lambda x:x[0])
# Out:
# 11             Ranveer Singh
# 34              Gavie Chahal
# 37        Ayushmann Khurrana
# 87         Sidharth Malhotra
# 96                Ajay Devgn
#                 ...
# 1600             Divya Dutta
# 1601               Anant Nag
# 1607             Anil Kapoor
# 1621    Priyanshu Chatterjee
# 1623          Karisma Kapoor
# Name: actors, Length: 298, dtype: object
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
movies.sample()
# Out:
#                        title_x    imdb_id  \
# 171  Rangoon (2017 Hindi film)  tt4909752
#
#                                            poster_path  \
# 171  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link  title_y  \
# 171  https://en.wikipedia.org/wiki/Rangoon_(2017_Hi...  Rangoon
#
#     original_title  is_adult  year_of_release runtime                genres  \
# 171        Rangoon         0             2017     170  Action|Drama|History
#
#      imdb_rating  imdb_votes  \
# 171          5.7        3393
#
#                                                  story  \
# 171  A love triangle forms against the backdrop of ...
#
#                                                summary             tagline  \
# 171  A love triangle forms against the backdrop of ...  Love. War. Deceit.
#
#                                                 actors       wins_nominations  \
# ...

# %%
# important dataframe functions
ipl.info()
ipl["ID"]=ipl["ID"].astype("int32")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
