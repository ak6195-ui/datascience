# %%
#astype
#between 
#clip
#drop_duplicates
#isnull
#dropna
#fillna
#isin
#apply 
# copy

# %%
import pandas as pd
import numpy as np

# %%
subs=pd.read_csv("subs.csv").squeeze("columns")
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
movies=pd.read_csv("bollywood.csv",index_col="movie").squeeze("columns")
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
koli=pd.read_csv("kohli_ipl.csv",index_col="match_no").squeeze("columns")
koli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
#astype
koli=koli.astype("int16")

# %%
koli.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 215 entries, 1 to 215
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int16
# dtypes: int16(1)
# memory usage: 2.1 KB

# %%
koli[koli.between(1,10)]
# Out:
# match_no
# 1       1
# 5       1
# 6       9
# 10      3
# 11     10
# 13      3
# 16      2
# 25      7
# 26      2
# 35      3
# 38      9
# 53      8
# 55      8
# 56      6
# 60      4
# 64      9
# 66      9
# 67      3
# 75      1
# 77      1
# 90      4
# 94      4
# 95     10
# 106     1
# 113     1
# 125     7
# 136    10
# 139     6
# 140     5
# 150     8
# 155     4
# 156     6
# 158     3
# 163     8
# 165     9
# 171     9
# 172     7
# 174     1
# 183     8
# 184     6
# 187     5
# 189     8
# 192     5
# 194     5
# 195     4
# 202     5
# 204     1
# 208     9
# 215     7
# Name: runs, dtype: int16

# %%
#clip 
koli.clip(100,200)
# Out:
# match_no
# 1      100
# 2      100
# 3      100
# 4      100
# 5      100
#       ...
# 211    100
# 212    100
# 213    100
# 214    100
# 215    100
# Name: runs, Length: 215, dtype: int16

# %%
#drop_duplicates
temp=pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates(keep="last")
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
temp=pd.Series([1,1,np.nan,2,2,np.nan])
temp.dropna().astype("int64")
# Out:
# 0    1
# 1    1
# 3    2
# 4    2
# dtype: int64

# %%
koli.isnull().sum()
# Out:
# np.int64(0)

# %%
temp.fillna(temp.mean()).astype("int64")
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# 5    1
# dtype: int64

# %%
#isin()
koli.isin([1,2,3])
# Out:
# match_no
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 211    False
# 212    False
# 213    False
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
movies.str.split(" ").apply(lambda x:x[0])
# Out:
# movie
# Uri: The Surgical Strike                  Vicky
# Battalion 609                             Vicky
# The Accidental Prime Minister (film)     Anupam
# Why Cheat India                          Emraan
# Evening Shadows                            Mona
#                                          ...
# Hum Tumhare Hain Sanam                     Shah
# Aankhen (2002 film)                     Amitabh
# Saathiya (film)                           Vivek
# Company (film)                             Ajay
# Awara Paagal Deewana                     Akshay
# Name: lead, Length: 1500, dtype: object

# %%
subs.apply(lambda x:x if x>subs.mean() else np.nan)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 360    231.0
# 361    226.0
# 362    155.0
# 363    144.0
# 364    172.0
# Name: Subscribers gained, Length: 365, dtype: float64

# %%
#copy
koli.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int16

# %%
new=koli.head().copy()

# %%
new[1]=100
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int16

# %%
koli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int16

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 koli.astype()
#
# TypeError: NDFrame.astype() missing 1 required positional argument: 'dtype'
