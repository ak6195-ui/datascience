# %%
import numpy as np 
import pandas as pd

# %%
ipl=pd.read_csv("ipl.csv")
ipl.sample()
# Out:
#          ID       City        Date Season MatchNumber  \
# 398  980969  Bangalore  2016-05-07   2016          35
#
#                            Team1                    Team2  \
# 398  Royal Challengers Bangalore  Rising Pune Supergiants
#
#                      Venue                   TossWinner TossDecision  \
# 398  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
#
#     SuperOver                  WinningTeam    WonBy  Margin method  \
# 398         N  Royal Challengers Bangalore  Wickets     7.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 398         V Kohli  ['V Kohli', 'KL Rahul', 'AB de Villiers', 'SR ...
#
#                                           Team2Players      Umpire1  \
# 398  ['AM Rahane', 'UT Khawaja', 'SS Tiwary', 'MS D...  CB Gaffaney
#
#           Umpire2
# 398  BNJ Oxenford

# %%
ipl["ALL-PLAYER"]=ipl["Team1Players"]+ipl["Team2Players"]

# %%
ipl["ALL-PLAYER"]
# Out:
# 0      ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#                              ...
# 945    ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# Name: ALL-PLAYER, Length: 950, dtype: object

# %%
def did_koli_play(players):
    return "V Kohli" in players

# %%
ipl["did_koli_play"]=ipl["ALL-PLAYER"].apply(did_koli_play)

# %%
ipl[(ipl["did_koli_play"]==True)&(ipl["City"]=="Delhi")].loc[:,["Date","Season","did_koli_play","City"]].sort_values("Date")
# Out:
#            Date   Season  did_koli_play   City
# 933  2008-04-30  2007/08           True  Delhi
# 801  2010-04-04  2009/10           True  Delhi
# 746  2011-04-26     2011           True  Delhi
# 638  2012-05-17     2012           True  Delhi
# 571  2013-05-10     2013           True  Delhi
# 467  2015-04-26     2015           True  Delhi
# 318  2017-05-14     2017           True  Delhi
# 269  2018-05-12     2018           True  Delhi
# 208  2019-04-28     2019           True  Delhi

# %%
ipl.drop(columns=["Date","City"]).sample()
# Out:
#          ID Season MatchNumber                Team1  \
# 52  1304068   2022          22  Chennai Super Kings
#
#                           Team2                               Venue  \
# 52  Royal Challengers Bangalore  Dr DY Patil Sports Academy, Mumbai
#
#                      TossWinner TossDecision SuperOver          WinningTeam  \
# 52  Royal Challengers Bangalore        field         N  Chennai Super Kings
#
#    WonBy  Margin method Player_of_Match  \
# 52  Runs    23.0    NaN          S Dube
#
#                                          Team1Players  \
# 52  ['RD Gaikwad', 'RV Uthappa', 'MM Ali', 'S Dube...
#
#                                          Team2Players      Umpire1   Umpire2  \
# 52  ['F du Plessis', 'Anuj Rawat', 'V Kohli', 'GJ ...  Nitin Menon  N Pandit
#
#                                            ALL-PLAYER  did_koli_play
# 52  ['RD Gaikwad', 'RV Uthappa', 'MM Ali', 'S Dube...           True

# %%
ipl.drop(index=[1,2,3]) #index baneko chai row hatauni type ko bhayo
# Out:
#           ID        City        Date   Season MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022       Final
# 4    1304116      Mumbai  2022-05-22     2022          70
# 5    1304115      Mumbai  2022-05-21     2022          69
# 6    1304114      Mumbai  2022-05-20     2022          68
# 7    1304113      Mumbai  2022-05-19     2022          67
# ..       ...         ...         ...      ...         ...
# 945   335986     Kolkata  2008-04-20  2007/08           4
# 946   335985      Mumbai  2008-04-20  2007/08           5
# 947   335984       Delhi  2008-04-19  2007/08           3
# 948   335983  Chandigarh  2008-04-19  2007/08           2
# 949   335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# 5                 Delhi Capitals               Mumbai Indians
# ...

# %%
bat=pd.read_csv("batman.csv")
bat.sample()
bat["batsman_run"].rank(axis=0,ascending=False)
# Out:
# 0      166.5
# 1      226.0
# 2      535.0
# 3      329.0
# 4      402.5
#        ...
# 600    594.0
# 601    343.0
# 602    547.5
# 603     27.0
# 604    256.0
# Name: batsman_run, Length: 605, dtype: float64

# %%
temp = pd.Series([10,20,30,40,50])

# %%
def sigmoid(value):
    return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.000045
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
    pt_A=row["1st point"]
    pt_B=row["2nd point"]
    return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(euclidean,axis=1)
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
