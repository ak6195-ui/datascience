# %%
import pandas as pd 
import numpy as np

# %%
# series from list 
country=["nepal","india","pakistan","usa"]
pd.Series(country )
# Out:
# 0       nepal
# 1       india
# 2    pakistan
# 3         usa
# dtype: str

# %%
runs=[31,24,56,78,100]
pd.Series(runs)
# Out:
# 0     31
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
marks=[68,87,66]
subject=["maths","english","science"]
pd.Series(marks,index=subject)
# Out:
# maths      68
# english    87
# science    66
# dtype: int64

# %%
#setting name 
M=pd.Series(marks,index=subject,name="abi ko marks")
M
# Out:
# maths      68
# english    87
# science    66
# Name: abi ko marks, dtype: int64

# %%
#SERIES FROM DICTONARY 
marks={"maths":99,"english":99,"comp":99}
marks_s=pd.Series(marks,name="abi ko marks")
marks_s
# Out:
# maths      99
# english    99
# comp       99
# Name: abi ko marks, dtype: int64

# %%
#ATTRIBUTE

# %%
marks_s.size
# Out:
# 3

# %%
marks_s.dtype
# Out:
# dtype('int64')

# %%
marks_s.name
# Out:
# 'abi ko marks'

# %%
marks_s.is_unique#if repeat then false and if not then true
# Out:
# False

# %%
marks_s.index
# Out:
# Index(['maths', 'english', 'comp'], dtype='str')

# %%
marks_s.values
# Out:
# array([99, 99, 99])

# %%
subs=pd.read_csv("subs.csv").squeeze("columns")
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
koli=pd.read_csv("kohli_ipl.csv",index_col="match_no").squeeze("columns")
koli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
koli_2=pd.read_csv("kohli_ipl.csv",index_col="runs").squeeze("columns")
koli_2 # read_csv("name" , index_col="name") le chai index ni halna milxa hai
# Out:
# runs
# 1       1
# 23      2
# 13      3
# 12      4
# 1       5
#      ...
# 0     211
# 20    212
# 73    213
# 25    214
# 7     215
# Name: match_no, Length: 215, dtype: int64

# %%
movies=pd.read_csv("bollywood.csv",index_col="movie").squeeze("columns")
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
#name is set on basis of value

# %%
#series method
#head and tail
subs.head() # first .head(number)
subs.tail() #last    .tail(number)
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
movies.sample(3)
# Out:
# movie
# 22 Yards                  Barun Sobti
# Bhagmati (2005 film)             Tabu
# Dum (2003 Hindi film)    Vivek Oberoi
# Name: lead, dtype: str

# %%
# .value_counts() -> frequency count of values
movies.value_counts().sort_values(ascending=False)
# frequency count garna ko lagi chai hamle .value_counts gaxam hai 
movies.value_counts().sort_values(ascending=False)
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Mouli Ganguly        1
# Nargis Fakhri        1
# Sara Arjun           1
# Aisha Ahmed          1
# Salil Acharya        1
# Name: count, Length: 566, dtype: int64

# %%
koli.sort_values(ascending=False).values[0]
# Out:
# np.int64(113)

# %%
koli.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
# koli.sort_values(by="match_no",inplace=True)
movies.sort_index(inplace=True)

# %%
koli.sort_index(inplace=True)

# %%
movies.sort_index(ascending=False,inplace=True)
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: str

# %%
#mathematical method 
movies.size 
# .size le chai hamlai kati ota values xa bhanera dinxa hai
# Out:
# 1500

# %%
movies.count()
# Out:
# np.int64(1500)

# %%
koli.product()
# Out:
# np.int64(0)

# %%
subs.mean()
koli.median()
# Out:
# np.float64(24.0)

# %%
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: str

# %%
subs.std()
# Out:
# np.float64(62.6750230372527)

# %%
subs.var()
# Out:
# np.float64(3928.1585127201565)

# %%
subs.max()
# Out:
# np.int64(396)

# %%
subs.max()
# Out:
# np.int64(396)

# %%
koli.describe()
# .describe() le chai hamlai sab mean median mode ani std haru ni dinxa  sab dinxa sab
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
# series indexing

# %%
#integer indexing 
x=pd.Series([12,13,14,15,16,1,18,19])

# %%
#slicing 
#negative only works when index is str 
koli[4:15]
# Out:
# match_no
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# Name: runs, dtype: int64

# %%
koli[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# 2 States (2014 film)          Arjun Kapoor
# 1971 (2007 film)            Manoj Bajpayee
# 1920: The Evil Returns         Vicky Ahuja
# 1920: London                 Sharman Joshi
# 1920 (film)               Rajniesh Duggall
# Name: lead, dtype: str

# %%
#fancy indexing 
koli[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
#boolean indexing 
koli[koli>10]
# Out:
# match_no
# 2      23
# 3      13
# 4      12
# 7      34
# 9      21
#        ..
# 209    58
# 210    30
# 212    20
# 213    73
# 214    25
# Name: runs, Length: 157, dtype: int64

# %%
#editiing series

# %%
#using indexing 
marks_s[1]=100
marks_s
# Out:
# maths       99
# english     99
# comp        99
# 1          100
# Name: abi ko marks, dtype: int64

# %%
#if index dont exists 
marks_s["social"]=100

# %%
marks_s[2:]=100
marks_s
# Out:
# maths       99
# english     99
# comp       100
# 1          100
# social     100
# Name: abi ko marks, dtype: int64

# %%
marks_s
# Out:
# maths      99
# english    99
# comp       99
# Name: abi ko marks, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#using label 
movies.sample()
# Out:
# movie
# Dear Maya    Manisha Koirala
# Name: lead, dtype: object

# %%
movies["Dear Maya"]="rajesh hamal"

# %%
movies["Dear Maya"]
# Out:
# 'rajesh hamal'

# %%
import matplotlib.pyplot as plot

# %%
#series in python 
len(movies)
#type()
#dir
# Out:
# 1500

# %%
movies.shape
# Out:
# (1500,)

# %%
sorted(subs)
# Out:
# [33,
#  33,
#  35,
#  37,
#  39,
#  40,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  45,
#  46,
#  46,
#  48,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  50,
#  51,
#  54,
#  56,
#  56,
#  56,
#  56,
#  57,
#  61,
#  62,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  66,
#  67,
#  68,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  102,
#  102,
#  103,
#  103,
#  104,
#  104,
#  104,
#  105,
#  105,
#  105,
#  105,
#  105,
# ...

# %%
#min() and max()

# %%
#type conversion 
list(marks_s)
d=dict(marks_s)

# %%
#membership operator 
"2 States (2014 film)" in movies
# Out:
# True

# %%
" Vicky Ahuja" in movies #search only in index
# Out:
# False

# %%
"Vicky Ahuja" in movies.values
# Out:
# True

# %%
#looping 
for i in movies.index:
    print(i)
# Out:
# Zor Lagaa Ke...Haiya!
# Zokkomon
# Zindagi Tere Naam
# Zindagi Na Milegi Dobara
# Zindagi 50-50
# Zindaggi Rocks
# Zinda (film)
# Zila Ghaziabad
# Zid (2014 film)
# Zero (2018 film)
# Zeher
# Zed Plus
# Zameer: The Fire Within
# Zameen (2003 film)
# Zamaanat
# Yuvvraaj
# Yuva
# Yun Hota Toh Kya Hota
# Youngistaan
# Yeh Saali Aashiqui
# Yeh Mera India
# Yeh Lamhe Judaai Ke
# Yeh Khula Aasmaan
# Yeh Jawaani Hai Deewani
# Yeh Hai India
# Yeh Hai Bakrapur
# Yeh Dooriyan
# Yeh Dil
# Yatra (2007 film)
# Yamla Pagla Deewana: Phir Se
# Yamla Pagla Deewana
# Yakeen (2005 film)
# Yadvi – The Dignified Princess
# Yaaram (2019 film)
# Ya Rab
# Xcuse Me
# Woodstock Villa
# Woh Lamhe...
# Why Cheat India
# What's Your Raashee?
# What the Fish
# Well Done Abba
# Welcome to Sajjanpur
# Welcome Back (film)
# Welcome 2 Karachi
# Welcome (2007 film)
# Wedding Pullav
# Wedding Anniversary
# Waris Shah: Ishq Daa Waaris
# War Chhod Na Yaar
# Waqt: The Race Against Time
# Wanted (2009 film)
# Wake Up Sid
# ...

# %%
#operators  
#braodcasting 
100 -marks_s #code ot find how many number less than 100
# Out:
# maths        1
# english    100
# comp       100
# social       0
# Name: abi ko marks, dtype: int64

# %%
# relational operations

# %%
koli>100
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213    False
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
