# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv("move.csv")
ipl=pd.read_csv("ipl.csv")

# %%
marks=pd.DataFrame([[100,80,10],[90,70,7],[80,70,14],[80,70,14]],columns=["iq","marks","package"])
marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   80     70       14
# 3   80     70       14

# %%
marks.value_counts()
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# Name: count, dtype: int64

# %%
ipl.sample()
pfm=ipl.loc[:,["Player_of_Match"]].value_counts()
pfm
# Out:
# Player_of_Match
# AB de Villiers     25
# CH Gayle           22
# DA Warner          18
# RG Sharma          18
# MS Dhoni           17
#                    ..
# SW Billings         1
# Shoaib Akhtar       1
# TG Southee          1
# A Chandila          1
# Z Khan              1
# Name: count, Length: 262, dtype: int64

# %%
ipl[~ipl["MatchNumber"].str.isdigit()]["Player_of_Match"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Player_of_Match'>

# %%
ipl.sample()
ipl["TossDecision"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
ipl.sample()
(ipl["Team1"].value_counts() +ipl["Team2"].value_counts()).sort_values(ascending=True)
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Lucknow Super Giants            15
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Punjab Kings                    28
# Gujarat Lions                   30
# Pune Warriors                   46
# Delhi Capitals                  63
# Deccan Chargers                 75
# Sunrisers Hyderabad            152
# Delhi Daredevils               161
# Kings XI Punjab                190
# Rajasthan Royals               192
# Chennai Super Kings            208
# Kolkata Knight Riders          223
# Royal Challengers Bangalore    226
# Mumbai Indians                 231
# Name: count, dtype: int64

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

students.sort_values("name",na_position="first")
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
movies.head(2)
movies.sort_values(["year_of_release","title_x"],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
bat=pd.read_csv("batman.csv").squeeze("columns")
bat["rank"]=bat["batsman_run"].rank(ascending=False)
bat["rank"]=bat["rank"].astype("int64")
bat.sort_values("rank")
# Out:
#              batter  batsman_run  rank
# 569         V Kohli         6634     1
# 462        S Dhawan         6244     2
# 130       DA Warner         5883     3
# 430       RG Sharma         5881     4
# 493        SK Raina         5536     5
# ..              ...          ...   ...
# 570  V Pratap Singh            0   594
# 63     Abdur Razzak            0   594
# 562          U Kaul            0   594
# 65       Akash Deep            0   594
# 57           AS Roy            0   594
#
# [605 rows x 3 columns]

# %%
bat.sort_index()
# Out:
#              batter  batsman_run  rank
# 0    A Ashish Reddy          280   166
# 1          A Badoni          161   226
# 2        A Chandila            4   535
# 3          A Chopra           53   329
# 4       A Choudhary           25   402
# ..              ...          ...   ...
# 600      Yash Dayal            0   594
# 601   Yashpal Singh           47   343
# 602     Younis Khan            3   547
# 603    Yuvraj Singh         2754    27
# 604          Z Khan          117   256
#
# [605 rows x 3 columns]

# %%
#bat.set_index("batter",inplace=True)
#bat.reset_index("batter",inplace=True)

# %%
bat
# Out:
#              batter  batsman_run  rank
# 0    A Ashish Reddy          280   166
# 1          A Badoni          161   226
# 2        A Chandila            4   535
# 3          A Chopra           53   329
# 4       A Choudhary           25   402
# ..              ...          ...   ...
# 600      Yash Dayal            0   594
# 601   Yashpal Singh           47   343
# 602     Younis Khan            3   547
# 603    Yuvraj Singh         2754    27
# 604          Z Khan          117   256
#
# [605 rows x 3 columns]

# %%
# replace existing one without loosing 
bat.reset_index().set_index("batsman_run")
# Out:
#              index          batter  rank
# batsman_run
# 280              0  A Ashish Reddy   166
# 161              1        A Badoni   226
# 4                2      A Chandila   535
# 53               3        A Chopra   329
# 25               4     A Choudhary   402
# ...            ...             ...   ...
# 0              600      Yash Dayal   594
# 47             601   Yashpal Singh   343
# 3              602     Younis Khan   547
# 2754           603    Yuvraj Singh    27
# 117            604          Z Khan   256
#
# [605 rows x 3 columns]

# %%
#rename
bat.rename(columns={"batter":"batman"})
# Out:
#              batman  batsman_run  rank
# 0    A Ashish Reddy          280   166
# 1          A Badoni          161   226
# 2        A Chandila            4   535
# 3          A Chopra           53   329
# 4       A Choudhary           25   402
# ..              ...          ...   ...
# 600      Yash Dayal            0   594
# 601   Yashpal Singh           47   343
# 602     Younis Khan            3   547
# 603    Yuvraj Singh         2754    27
# 604          Z Khan          117   256
#
# [605 rows x 3 columns]

# %%
movies.sample(2)
#movies.set_index("title_x",inplace=True)
# Out:
#                            title_x    imdb_id  \
# 1372                  Phir Milenge  tt0422950
# 126   Yamla Pagla Deewana: Phir Se  tt7609114
#
#                                             poster_path  \
# 1372  https://upload.wikimedia.org/wikipedia/en/thum...
# 126   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1372         https://en.wikipedia.org/wiki/Phir_Milenge
# 126   https://en.wikipedia.org/wiki/Yamla_Pagla_Deew...
#
#                              title_y                  original_title  \
# 1372                    Phir Milenge                    Phir Milenge
# 126   Yamla Pagla Deewana Phir Se...  Yamla Pagla Deewana Phir Se...
#
#       is_adult  year_of_release runtime         genres  imdb_rating  \
# 1372         0             2004     142          Drama          6.1
# 126          0             2018     145  Action|Comedy          4.8
#
# ...

# %%
movies.rename(index={"Uri: The Surgical Strike":"HAHAHAH"})
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl["Season"].unique().shape[0]
# Out:
# 15

# %%
ipl["Season"].nunique()
# Out:
# 15

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl.notnull().count() #count dont count missing value but sum() gives
# Out:
# ID                 950
# City               950
# Date               950
# Season             950
# MatchNumber        950
# Team1              950
# Team2              950
# Venue              950
# TossWinner         950
# TossDecision       950
# SuperOver          950
# WinningTeam        950
# WonBy              950
# Margin             950
# method             950
# Player_of_Match    950
# Team1Players       950
# Team2Players       950
# Umpire1            950
# Umpire2            950
# dtype: int64

# %%
movies["title_x"].hasnans # has missing value or not 
movies.sample()
# Out:
#                  title_x    imdb_id  \
# 1442  Inteha (2003 film)  tt0385782
#
#                                             poster_path  \
# 1442  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link title_y original_title  \
# 1442  https://en.wikipedia.org/wiki/Inteha_(2003_film)  Inteha         Inteha
#
#       is_adult  year_of_release runtime          genres  imdb_rating  \
# 1442         0             2003     155  Drama|Thriller          5.3
#
#       imdb_votes                                              story  \
# 1442         131  Tina Saxena lives a wealthy life-style with he...
#
#                                                 summary  \
# 1442  Tina Saxena lives a wealthy life-style with he...
#
#                     tagline                                      actors  \
# 1442  One of them will die.  Ashmit Patel|Vidya Malvade|Nauheed Cyrusi|
#
#      wins_nominations             release_date
# ...

# %%
movies.drop("imdb_id",axis=1) #removing the column 
movies.set_index("title_x",inplace=True)

# %%
movies.reset_index(inplace=True)

# %%
movies.sample()
movies.drop(0) # removes the row in df
# Out:
#                                    title_x     imdb_id  \
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# 5                              Soni (film)   tt6078866
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...

# %%
movies.dropna() # removes the whole row if there is missing value
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.dropna(how="all") # if all value is missing value
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.dropna(subset="title_x")
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
students.sort_values("name",inplace=True)

# %%
students.dropna(how="all")
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
students.dropna(subset="name")
students.dropna(subset=["name","college"],how="any")
# Out:
#       name college branch  cgpa  package
# 1    ankit     iit     it  8.25      5.0
# 0   nitish     bit    eee  6.66      4.0
# 6  rishabh    ssit    civ  7.40      8.0
# 2   rupesh     vit    cse  6.41      6.0

# %%
students["name"].fillna("unknown")
students["package"].fillna(students["package"].mean())
# Out:
# 8    6.428571
# 1    5.000000
# 4    6.000000
# 0    4.000000
# 6    8.000000
# 2    6.000000
# 3    6.428571
# 5    7.000000
# 7    9.000000
# 9    6.428571
# Name: package, dtype: float64

# %%
students["name"].fillna(method="ffill") #gives the value from above -ffill
# gives the value from below -> bfill
# Out:
# C:\Users\My PC\AppData\Local\Temp\ipykernel_62060\1839807145.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students["name"].fillna(method="ffill") #gives the value from above -ffill
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# 3        rupesh
# 5        rupesh
# 7        rupesh
# 9        rupesh
# Name: name, dtype: object

# %%
students.duplicated()
marks.drop_duplicates()
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   80     70       14

# %%
ipl.sample()
# Out:
#          ID     City        Date   Season MatchNumber                  Team1  \
# 915  336017  Kolkata  2008-05-13  2007/08          35  Kolkata Knight Riders
#
#                 Team2         Venue             TossWinner TossDecision  \
# 915  Delhi Daredevils  Eden Gardens  Kolkata Knight Riders          bat
#
#     SuperOver            WinningTeam WonBy  Margin method Player_of_Match  \
# 915         N  Kolkata Knight Riders  Runs    23.0    NaN   Shoaib Akhtar
#
#                                           Team1Players  \
# 915  ['Salman Butt', 'A Chopra', 'SC Ganguly', 'DJ ...
#
#                                           Team2Players    Umpire1    Umpire2
# 915  ['G Gambhir', 'V Sehwag', 'AB de Villiers', 'M...  Asad Rauf  IL Howell

# %%
ipl[ipl[["Team1Players"]]+ipl["Team2Players"].str.split(" ").apply(lambda x: True if "V Kohli"in x else False)].loc[:,["Team1Players","Team2Players"]]
# Out:
#     Team1Players Team2Players
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 945          NaN          NaN
# 946          NaN          NaN
# 947          NaN          NaN
# 948          NaN          NaN
# 949          NaN          NaN
#
# [950 rows x 2 columns]

# %%
ipl[ipl[["Team1Players"]]+ipl["Team2Players"]]
# Out:
#      ID City Date Season MatchNumber Team1 Team2 Venue TossWinner  \
# 0   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 1   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 2   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 3   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 4   NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# ..   ..  ...  ...    ...         ...   ...   ...   ...        ...
# 945 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 946 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 947 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 948 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 949 NaN  NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
#
#     TossDecision SuperOver WinningTeam WonBy  Margin method Player_of_Match  \
# 0            NaN       NaN         NaN   NaN     NaN    NaN             NaN
# ...

# %%
ipl["all_players"]=ipl["Team1Players"]+ipl["Team2Players"]

# %%
def did_koli_play(players):
    return "V kohli" in players

# %%
ipl["did_koli_play"]=ipl["all_players"].apply(did_koli_play)

# %%
ipl.sample(3)
# Out:
#           ID     City        Date Season MatchNumber                  Team1  \
# 29   1304091   Mumbai  2022-05-01   2022          45   Lucknow Super Giants
# 628   548381  Chennai  2012-05-27   2012       Final  Kolkata Knight Riders
# 272  1136602    Delhi  2018-05-10   2018          42       Delhi Daredevils
#
#                    Team2                            Venue  \
# 29        Delhi Capitals         Wankhede Stadium, Mumbai
# 628  Chennai Super Kings  MA Chidambaram Stadium, Chepauk
# 272  Sunrisers Hyderabad             Arun Jaitley Stadium
#
#                TossWinner TossDecision  ...    WonBy Margin method  \
# 29   Lucknow Super Giants          bat  ...     Runs    6.0    NaN
# 628   Chennai Super Kings          bat  ...  Wickets    5.0    NaN
# 272      Delhi Daredevils          bat  ...  Wickets    9.0    NaN
#
#      Player_of_Match                                       Team1Players  \
# 29       Mohsin Khan  ['Q de Kock', 'KL Rahul', 'DJ Hooda', 'MP Stoi...
# ...

# %%
ipl[(ipl["City"]=="Delhi")&(ipl["did_koli_play"]==True)]#.loc[:,["City","did_koli_play","Date"]]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2, all_players, did_koli_play]
# Index: []
#
# [0 rows x 22 columns]

# %%
ipl["did_koli_play"]==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: did_koli_play, Length: 950, dtype: bool
