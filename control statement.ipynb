# %% [markdown]
# # conditonal statement

# %%
#if

# %%
x=1
if x>1:
    print(f"{x} is positive")
    print(x)
print("haina")
# Out:
# haina

# %%
xx=33
yy=-33
if xx>0 and yy>0:
    print("ho")
else :
