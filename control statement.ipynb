# %% [markdown]
# # conditonal statement

# %%
#if

# %%
x=1
if x>1:
    print(f"{x} is positive")
    print(x)
print("haina")
# Out:
# haina

# %%
xx=33
yy=-33
if xx>0 and yy>0:
    print(f"{xx} ra {yy}chai ho")
else :
    print(f" {xx} ra {yy} haina")
# Out:
#  33 ra -33 haina

# %%
a="rar"
if(a==a[::-1]):
    print(f" {a} chai ho")
else:
    print("haina")
# Out:
#  rar chai ho

# %%
w=1
e=2
if(e%w==0):
    print("la")
elif(w/e==0):
    print("lala")
else:
    print("nai")
# Out:
# la

# %% [markdown]
# # nested if

# %%
a=2
if (a>0):
    if(a>1):
        print("khatra")
    elif(a>2):
        print("jhan khata")
else:
    print("haaava")
# Out:
# khatra

# %%
if not {}:
    print("1")
# Out:
# 1

# %%
if  {}:
    print("0")
