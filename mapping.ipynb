# %% [markdown]
# DICTONARY # watch pep style

# %%
dit={"name":"abi","surname":"khadka","age":10
    ,"subject":["maths","science","comp"]}
dit
# Out:
# {'name': 'abi',
#  'surname': 'khadka',
#  'age': 10,
#  'subject': ['maths', 'science', 'comp']}

# %% [markdown]
# laka = dict(name="mk")
#  print(laka)

# %%
dit["name"]
# Out:
# 'abi'

# %%
dit.keys()
# Out:
# dict_keys(['name', 'surname', 'age', 'subject'])

# %%
dit.get("ola",50 )# dont gives error na huda pani 
# second comma ma value halna ni milxa
# Out:
# 50

# %%
dit.get("college name ","no name") #yedi xaina bhani comma paxi ko dekhau xa 
# xa bhani orginal value nai dekhaxa
# Out:
# 'no name'

# %%
dit.pop("surname")
# Out:
# 'khadka'

# %%
dit
# Out:
# {'name': 'abi', 'age': 10, 'subject': ['maths', 'science', 'comp']}

# %%
dit["surname"]="khadka"
print(dit)
# Out:
# {'name': 'abi', 'age': 10, 'subject': ['maths', 'science', 'comp'], 'surname': 'khadka'}

# %%
del dit["age"]

# %%
dit
# Out:
# {'name': 'abi', 'subject': ['science', 'comp'], 'surname': 'khadka'}

# %%
#.pop item removes last key and value

# %% [markdown]
#  # print dictonary methods
# keys() values() items() copy() clear()

# %%
dit.keys()
# Out:
# dict_keys(['name', 'subject', 'surname'])

# %%
dit.values()
# Out:
# dict_values(['abi', ['science', 'comp'], 'khadka'])

# %%
dit.items() #convert dictonary into list
# Out:
# dict_items([('name', 'abi'), ('subject', ['science', 'comp']), ('surname', 'khadka')])

# %% [markdown]
# MERGE dictonary

# %%
marks={"la":90,"k":80}

# %%
uu=dit|marks
print(uu)
# Out:
# {'name': 'abi', 'subject': ['science', 'comp'], 'surname': 'khadka', 'la': 90, 'k': 80}

# %%
{**dit,**marks} #merge methods
# Out:
# {'name': 'abi',
#  'subject': ['science', 'comp'],
#  'surname': 'khadka',
#  'la': 90,
#  'k': 80}

# %%
dict(zip(dit,marks))
# Out:
# {'name': 'la', 'subject': 'k'}

# %% [markdown]
# SORTED METHOD

# %%
uu
# Out:
# {'name': 'abi',
#  'subject': ['science', 'comp'],
#  'surname': 'khadka',
#  'la': 90,
#  'k': 80}

# %%
sorted(uu) #yesle keys matra dinxa
sorted(uu.items()) #items le value ni dinxa
dict(sorted(uu.items()))
# Out:
# {'k': 80,
#  'la': 90,
#  'name': 'abi',
#  'subject': ['science', 'comp'],
#  'surname': 'khadka'}

# %%
dict(sorted(uu.items(),reverse=True))
# Out:
# {'surname': 'khadka',
#  'subject': ['science', 'comp'],
#  'name': 'abi',
#  'la': 90,
#  'k': 80}

# %%
#according to value 
abi={"name":"abi","age":"10","location":"nepal"}
dict(sorted(abi.items(),
            key= lambda item: item[1],
            reverse=False)
    )
# Out:
# {'age': '10', 'name': 'abi', 'location': 'nepal'}
