# %%
print("feri suru huss")
# Out:
# feri suru huss

# %%
print(1+2)
# Out:
# 3

# %%
print(1//2)
# Out:
# 0

# %%
complex(1,2)
# Out:
# (1+2j)

# %%
not True
# Out:
# False

# %%
fruits=["apple","bannaa","mangoo"]
x,y,z=fruits
print(x)
# Out:
# apple

# %%
x="python"
y="is"
z="dammi"
print(x+y+z)
# Out:
# pythonisdammi

# %%
a="abi khadka"
def abi():
    global a
    a="khadka"
    print(a)
abi()
print(a)
# Out:
# khadka
# khadka

# %%
#slicing 
abi="abi and khadka"
print(len(abi))
print(abi[0:9])
print(abi.upper())
# abi=abi.upper()
print(abi.lower())
greet="NAMASTE"
print(greet.replace("N","H"))
name=abi.split("and")
print(name)
print("my name is \"ola\" from nepal")
abi.count("a")
print(abi.endswith("a"))
print(abi[::-1])
# Out:
# 14
# abi and k
# ABI AND KHADKA
# abi and khadka
# HAMASTE
# ['abi ', ' khadka']
# my name is "ola" from nepal
# True
# akdahk dna iba

# %%
#list 
listt=["abi","khadka","is","good"]
print(listt[0][0])
print(len(listt))
print(listt[::-1])
if "abi" in listt:
    print("herp")
listt.insert(4,"lamoo")
listt[2]="and"
print(listt)
lala=[x for x in listt]
print(lala)
ok=[1,2,3,4,5,6]
aa=[x for x in ok if x%2==0]
#print(aa)
def abi(a):
    print("la haii")
    ok=[x for x in a if x%2==0]
    print(ok)
abi(ok)
# Out:
# a
# 4
# ['good', 'is', 'khadka', 'abi']
# herp
# ['abi', 'khadka', 'and', 'good', 'lamoo']
# ['abi', 'khadka', 'and', 'good', 'lamoo']
# la haii
# [2, 4, 6]

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
tup=(1,2,3)
tup1=(5,6,7)
print(tup*2)
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
child1={"name":"abi","age":18}
child2={"name":"ola","age":11}
dicto={"child1":child1,"child2":child2}
print(dicto["child1"]["name"])
# Out:
# abi

# %%
a="abi"
if isinstance(a,str):
    print("thikxa")
else:
    raise Error(f"wrong xa hai ")
# Out:
# thikxa

# %%
def age(a):
    if a>18:
        print("PASS")
    else:
        raise age_below_18(f"FAIL")
age(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4     else:
#       5         raise age_below_18(f"FAIL")
# ----> 6 age(1)
#
# Cell In[8], line 5, in age(a)
#       3     print("PASS")
#       4 else:
# ----> 5     raise age_below_18(f"FAIL")
#
# NameError: name 'age_below_18' is not defined

# %%
def money_check(wit):
    amt=1800000
    if wit<amt:
        print("sucessful")
    else:
        raise NOMONEY(f"paisa pugena ")
money_check(1800)
# Out:
# sucessful

# %%
try:
    a=int(input("enter your age "))
    b=int(input("enter your id "))
    result=a/b
except ValueError as e:
    print(e)
    print("INVALUD INPUT ",e)
    result =1
except  ZeroDivisionError:
    print("cannot divide by 0")
    result=2
except Exception as ee:
    print(ee)
    result=3
else:
    print("final result is ",result)
finally:
    print("END")
# Out:
# invalid literal for int() with base 10: 'a'
# INVALUD INPUT  invalid literal for int() with base 10: 'a'
# END

# %%
lis=[1,2,3,4,5]
def get(index):
    return lis[index]
index=int(input("enter index"))
try:
    result=f=get(index)
except IndexError:
    print("INDEX OUT OF RANGE OS LAST ELEMENT IS:\n")
    result=get(-1)
finally:
    print(result)
# Out:
# INDEX OUT OF RANGE OS LAST ELEMENT IS:
#
# 5
