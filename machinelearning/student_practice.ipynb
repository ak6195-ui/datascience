# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plot
import seaborn as sns

# %%
raw_data=pd.read_csv("StudentPerformanceFactors.csv")
raw_data.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
raw_data.columns
raw_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6529 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %%
raw_data.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='str')

# %%
raw_data.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
def fill_null(series):
    return series.fillna(series.mode()[0])

# %%
raw_data["Teacher_Quality"]=fill_null(raw_data["Teacher_Quality"])

# %%
raw_data["Parental_Education_Level"]=fill_null(raw_data["Parental_Education_Level"])

# %%
raw_data["Distance_from_Home"]=fill_null(raw_data["Distance_from_Home"])

# %%
raw_data.head()
raw_data.duplicated().sum()
#so the null values are filled and there is no duplicated row then we move foward
# Out:
# np.int64(0)

# %%
columns=['Hours_Studied', 'Attendance', 'Sleep_Hours',
       'Previous_Scores',
       'Tutoring_Sessions',
       'Physical_Activity',
       'Exam_Score']
for column in columns:
       fig,axes=plot.subplots(1,2,figsize=(12,8))
       axes[0].hist(raw_data[column])
       axes[0].set_title(f"HISTOGRAM-{column}")
       axes[0].set_xlabel(column)
       axes[0].set_ylabel("FREQUENCY")
       axes[1].boxplot(raw_data[column])
       axes[1].set_title(f"BOXPLOT-{column}")
       axes[1].set_xlabel(column)
       plot.tight_layout()
       plot.show()

# %%
raw_data.info()
raw_data
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6607 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %%
# NOW LOOK INTO THE DATA TYPES AND DO ENCODING ACCORDING 
# for the data having order we do ordinal encodeing for label yes/no etc we do label encoding and if there is no relation between them then use ONEHOTENCODER

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,OrdinalEncoder
onehot=OneHotEncoder(sparse_output=False)
label=LabelEncoder()
ordinal=OrdinalEncoder(categories=[["Low","Medium","High"]])
# parental involvement is for ordinal encoder 
raw_data["Parental_Involvement"]=ordinal.fit_transform(raw_data[["Parental_Involvement"]])

# %%
raw_data["Parental_Involvement"]=raw_data["Parental_Involvement"].astype(int)

# %%
from sklearn.preprocessing import OrdinalEncoder 
for_Access=OrdinalEncoder(categories=[["Low","Medium","High"]])
raw_data["Access_to_Resources"]=for_Access.fit_transform(raw_data[["Access_to_Resources"]])

# %%
raw_data["Access_to_Resources"]=raw_data["Access_to_Resources"].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder 
extra=LabelEncoder()
raw_data["Extracurricular_Activities"]=extra.fit_transform(raw_data["Extracurricular_Activities"])

# %%
raw_data["Motivation_Level"]=for_Access.fit_transform(raw_data[["Motivation_Level"]])

# %%
raw_data["Motivation_Level"]=raw_data["Motivation_Level"].astype(int)

# %%
raw_data["Family_Income"]=for_Access.fit_transform(raw_data[["Family_Income"]])

# %%
raw_data["Family_Income"]=raw_data["Family_Income"].astype(int)

# %%
raw_data["Internet_Access"]=extra.fit_transform(raw_data["Internet_Access"])

# %%
raw_data["Teacher_Quality"]=for_Access.fit_transform(raw_data[["Teacher_Quality"]])

# %%
raw_data["Teacher_Quality"]=raw_data["Teacher_Quality"].astype(int)

# %%
from sklearn.preprocessing import OneHotEncoder 
type=OneHotEncoder(sparse_output=False)
type_result=type.fit_transform(raw_data[["School_Type"]])
new=pd.DataFrame(type_result,columns=type.get_feature_names_out(["School_Type"]),index=raw_data.index)

# %%
from sklearn.preprocessing import OneHotEncoder 
lala=OneHotEncoder(sparse_output=False)
out=lala.fit_transform(raw_data[["School_Type"]])
new=pd.DataFrame(out,columns=lala.get_feature_names_out(["School_Type"]),index=raw_data.index)

# %%
raw_dat=pd.concat([raw_data,new],axis=1)
raw_dat.drop("School_Type",axis=1,inplace=True)

# %%
from sklearn.preprocessing import OneHotEncoder
peer=OneHotEncoder(sparse_output=False)
raw=peer.fit_transform(raw_dat[["Peer_Influence"]])
new=pd.DataFrame(raw,columns=peer.get_feature_names_out(["Peer_Influence"]),index=raw_dat.index)

# %%
raw_dat=pd.concat([raw_dat,new],axis=1)

# %%
raw_dat.rename(columns={"Peer_Influence_0":"Peer_Influence_positive","Peer_Influence_1":"Peer_Influence_negative","Peer_Influence_2":"Peer_Influence_neutral"},inplace=True)

# %%
raw_dat.drop("Learning_Disabilities",inplace=True,axis=1)

# %%
raw_dat.drop(["Parental_Education_Level","Distance_from_Home","Gender"],axis=1,inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler()
col=["Hours_Studied","Attendance","Previous_Scores","Exam_Score"]
raw_dat[col]=minmax.fit_transform(raw_dat[col])

# %%
raw_dat.drop("Physical_Activity",inplace=True,axis=1)

# %%
raw_dat
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0          0.511628       0.600                     0                    2
# 1          0.418605       0.100                     0                    1
# 2          0.534884       0.950                     1                    1
# 3          0.651163       0.725                     0                    1
# 4          0.418605       0.800                     1                    1
# ...             ...         ...                   ...                  ...
# 6602       0.558140       0.225                     2                    1
# 6603       0.511628       0.400                     2                    1
# 6604       0.441860       0.750                     1                    0
# 6605       0.209302       0.650                     2                    2
# 6606       0.325581       0.175                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
lala=MinMaxScaler()
raw_dat["Sleep_Hours"]=lala.fit_transform(raw_dat[["Sleep_Hours"]])

# %%
raw_dat.info()
#Parential_Involvement,Motivation_level,Tutoring_Sessions,Family_Income,Peer_Infulance,School_Type_Private
final_data=raw_dat.drop(['Parental_Involvement','Extracurricular_Activities','Sleep_Hours','Previous_Scores','Family_Income',
       'Peer_Influence',"School_Type_Private","School_Type_Public","Peer_Influence_Negative","Peer_Influence_Neutral","Peer_Influence_Positive"],axis=1)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   float64
#  1   Attendance                  6607 non-null   float64
#  2   Parental_Involvement        6607 non-null   int64
#  3   Access_to_Resources         6607 non-null   int64
#  4   Extracurricular_Activities  6607 non-null   int64
#  5   Sleep_Hours                 6607 non-null   float64
#  6   Previous_Scores             6607 non-null   float64
#  7   Motivation_Level            6607 non-null   int64
#  8   Internet_Access             6607 non-null   int64
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   int64
#  11  Teacher_Quality             6607 non-null   int64
#  12  Peer_Influence              6607 non-null   str
# ...

# %%
raw_dat.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality',
#        'Peer_Influence', 'Exam_Score', 'School_Type_Private',
#        'School_Type_Public', 'Peer_Influence_Negative',
#        'Peer_Influence_Neutral', 'Peer_Influence_Positive'],
#       dtype='str')

# %%
final_data
cross=pd.crosstab(final_data["Hours_Studied"],final_data["Exam_Score"])
from scipy import stats
chi2_value,p_value,dof,expected=stats.chi2_contingency(cross)

# %%
chi2_value,p_value
final_data.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Access_to_Resources',
#        'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions',
#        'Teacher_Quality', 'Exam_Score'],
#       dtype='str')

# %%
columns=['Hours_Studied', 'Attendance', 'Access_to_Resources',
       'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions',
       'Teacher_Quality']
def check_chi2(i,column2):
    from scipy import stats
    cross=pd.crosstab(final_data[i],final_data[column2])
    chi2_value,p_value,dof,expected=stats.chi2_contingency(cross)
    return f"chi2_value:{chi2_value},p_value:{p_value} \n"
for i in columns:
    print(f"THE RESULT FOR {i} and Exam_Score :{check_chi2(i,"Exam_Score")}")
# Out:
# THE RESULT FOR Hours_Studied and Exam_Score :chi2_value:9134.194702692468,p_value:0.0
#
# THE RESULT FOR Attendance and Exam_Score :chi2_value:5596.168448850054,p_value:0.0
#
# THE RESULT FOR Access_to_Resources and Exam_Score :chi2_value:357.78505037631714,p_value:3.2113423782389325e-34
#
# THE RESULT FOR Motivation_Level and Exam_Score :chi2_value:141.87537810559536,p_value:0.000241659632576963
#
# THE RESULT FOR Internet_Access and Exam_Score :chi2_value:72.93996881514428,p_value:0.003949299752021104
#
# THE RESULT FOR Tutoring_Sessions and Exam_Score :chi2_value:835.1374941817679,p_value:2.905870043003732e-41
#
# THE RESULT FOR Teacher_Quality and Exam_Score :chi2_value:125.29538874532633,p_value:0.005558039210403978

# %%
from scipy.stats import f_oneway
f_stat,p_value=f_oneway(final_data["Hours_Studied"],final_data["Exam_Score"])
# this is for categorical and numerical  features

# %%
final_data["Exam_Score"].corr(final_data["Hours_Studied"])
# Out:
# np.float64(0.44545495407528163)

# %%
columns=['Hours_Studied', 'Attendance', 'Access_to_Resources',
       'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions',
       'Teacher_Quality']
for column in columns:
    fig,axes=plot.subplots(1,1,figsize=(5,4))
    axes.scatter(x=final_data[column],y=final_data["Exam_Score"])
    axes.set_xlabel("Exam_Score")
    axes.set_ylabel(column)
    axes.set_title(f"Scatter plot between Exam_Score and {column}")
    plot.tight_layout()
    plot.show()

# %%
# hours studied and attendence can be done using linear regression 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
# so firstly the prediction is going to be on exam score so 
y=final_data["Exam_Score"]
#and the most suitable features are hours_studied and attendance 
x=final_data[["Hours_Studied","Attendance"]]
# so now firstly split the data on test and train datas for model 
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
#now lets test our model 
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)
print(f"mae {mae}\n mse{mse} \n rmse {rmse}\n r2 {r2}\n")
# Out:
# mae 0.03326950688457726
#  mse0.0029153568534927396
#  rmse 0.05399404461135265
#  r2 0.575836648425835
