# %% [markdown]
# #  SET

# %%
set1={1,2,3,4,5,5,6}
type(set1)
# Out:
# set

# %%
print(set1) #unique number  hunxa repeat hudaina
# ascending order ma rakhxa
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # MODIFICATION

# %%
set1.add(9)
set1
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
set1.update(["abi"]) #update ma iterable haru halxan ani multiple halxan
set1
# Out:
# {1, 2, 3, 4, 5, 6, 9, 'abi'}

# %%
a=set()
type(a)
# Out:
# set

# %%
set1.pop()
set1
# Out:
# {5, 6, 9, 'abi'}

# %%
set1
# Out:
# {5, 6, 9, 'abi'}

# %%
set1.remove(5)

# %%
set1
# Out:
# {6, 9, 'abi'}

# %%
set1.discard(11) #dont shows error
set1

# %% [markdown]
# # set operations

# %%
a={1,2,3,4}
b={4,5,6,7}

# %%
a.union(b) 
a|b
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a.intersection(b)
a&b
# Out:
# {4}

# %%
a^b # symmetric_difference le intersection baheak sab add garxa
# Out:
# {1, 2, 3, 5, 6, 7}
