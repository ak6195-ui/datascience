# %% [markdown]
# # RAISE IS USED TO DEFINE ERROR BY USER:
# raise ExceptionType('message')

# %%
number="ii"

# %%
if isinstance(number,int):
    print(f"square of {number}  is {number**2} ")
else:
    raise TypeError(f"value should be int")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2     print(f"square of {number}  is {number**2} ")
#       3 else:
# ----> 4     raise TypeError(f"value should be int")
#
# TypeError: value should be int

# %% [markdown]
# # USER DEFINED EXCEPTION

# %%
class Myexception(Exception):
    pass

# %%
class Invalidage(Exception):
    """RAISED WHEN THE INPUT VALUE IS LESS THAN 18"""
    pass

# %%
def check(id):
    age=12
    if "whiskey":
        if age>18:
            pass
        else:
            raise Invalidage("must be 18+")

# %%
check(111)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 check(111)
#
# Cell In[35], line 7, in check(id)
#       5     print("sucessful")
#       6 else :
# ----> 7     raise  Nomoney("sorry witdrawl error ")
#
# TypeError: Nomoney() takes no arguments

# %%
# ATM EXCEPTION 
class Nomoney:
    """RAISE WHEN THE WITDRAWL IS GREATER THAN AMOUNT"""
    pass

# %%
def check(id):
    witdrawl=int(input("ENTER THE AMOUNT:\n"))
    account=1000
    if account>=witdrawl:
        print("sucessful")
    else :
        raise  Nomoney("sorry witdrawl error ")

# %%
check(123)
# Out:
# ENTER THE AMOUNT:
#  5000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 check(123)
#
# Cell In[42], line 7, in check(id)
#       5     print("sucessful")
#       6 else :
# ----> 7     raise  Nomoney("sorry witdrawl error ")
#
# TypeError: Nomoney() takes no arguments
